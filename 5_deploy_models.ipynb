# %% [markdown]
# ## 5. 모델 배포하기

# %%
### 1. query model 배포하기

# %%
inputs = {
  "predictions": {
    "scores": [
      0.6303086438567949,
      0.3791290627297427,
      0.5677551770392755,
      0.41242867714305065,
      0.42730690486438494,
      0.601529882743909,
      0.6260879998025899,
      0.601574127398539,
      0.5334478929879939,
      0.504259190115954,
      0.5937195210744586,
      0.5313247993825141,
      0.602544614079735,
      0.5838643667616848,
      0.4249618500178985,
      0.20798648640676326,
      0.2598100906865275,
      0.46320849437326467,
      0.4958446632768758,
      0.3969789858405491,
      0.3791290627297427,
      0.5123185170602064
    ],
    "article_ids": [
      "596097001",
      "581228001",
      "493438019",
      "669105001",
      "651273002",
      "658321004",
      "608007006",
      "625311009",
      "564786020",
      "564786023",
      "436570008",
      "710059001",
      "675827003",
      "615021009",
      "637820002",
      "664228002",
      "663383001",
      "637566003",
      "625316004",
      "704048003",
      "606712001",
      "699461001"
    ]
  }
}
preds = inputs["predictions"]
ranking = list(zip(preds["scores"], preds["article_ids"])) # merge lists
ranking.sort(reverse=True) # sort by score (descending)
print({ "ranking": ranking })
# Out:
# {'ranking': [(0.6303086438567949, '596097001'), (0.6260879998025899, '608007006'), (0.602544614079735, '675827003'), (0.601574127398539, '625311009'), (0.601529882743909, '658321004'), (0.5937195210744586, '436570008'), (0.5838643667616848, '615021009'), (0.5677551770392755, '493438019'), (0.5334478929879939, '564786020'), (0.5313247993825141, '710059001'), (0.5123185170602064, '699461001'), (0.504259190115954, '564786023'), (0.4958446632768758, '625316004'), (0.46320849437326467, '637566003'), (0.42730690486438494, '651273002'), (0.4249618500178985, '637820002'), (0.41242867714305065, '669105001'), (0.3969789858405491, '704048003'), (0.3791290627297427, '606712001'), (0.3791290627297427, '581228001'), (0.2598100906865275, '663383001'), (0.20798648640676326, '664228002')]}
